# %% [markdown]
# #Task2: Try Linear regression on same prediction data using Tensorflow

# %%
import numpy as np
import tensorflow as tf

# %%
inputs = np.array([[73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70],[73, 67, 43], [91, 88, 64], 
                   [87, 134, 58], [102, 43, 37], [69, 96, 70], [73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], 
                   [69, 96, 70]], dtype='float64')

targets = np.array([[56, 70], [81, 101], [119, 133], [22, 37], [103, 119],[56, 70], [81, 101], [119, 133], [22, 37], 
                    [103, 119],[56, 70], [81, 101], [119, 133], [22, 37], [103, 119]], dtype='float64')

# %%
inputs = tf.Variable(inputs)
targets = tf.Variable(targets)
print("targets :\n",targets)
# Out:
# targets :
#  <tf.Variable 'Variable:0' shape=(15, 2) dtype=float64, numpy=
# array([[ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.],
#        [ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.],
#        [ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.]])>

# %%
v = np.random.rand(3,2)
r = np.random.randn(2)
v = tf.Variable(v)
r = tf.Variable(r)

print(v)
print("\n",r)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[0.69696562, 0.56265268],
#        [0.36620476, 0.09873505],
#        [0.37247523, 0.44986804]])>
#
#  <tf.Variable 'Variable:0' shape=(2,) dtype=float64, numpy=array([1.61761891, 0.44536691])>

# %%
def model(s):
    return s @ v + r

# %%
prediction = model(inputs)
print(prediction)
# Out:
# tf.Tensor(
# [[ 93.04826316  67.47858662]
#  [121.10592411  89.12699973]
#  [132.92862928  88.71899303]
#  [102.23650063  78.72666499]
#  [110.93716983  80.23772935]
#  [ 93.04826316  67.47858662]
#  [121.10592411  89.12699973]
#  [132.92862928  88.71899303]
#  [102.23650063  78.72666499]
#  [110.93716983  80.23772935]
#  [ 93.04826316  67.47858662]
#  [121.10592411  89.12699973]
#  [132.92862928  88.71899303]
#  [102.23650063  78.72666499]
#  [110.93716983  80.23772935]], shape=(15, 2), dtype=float64)

# %%
def mse(t1,t2):
    return tf.reduce_mean(tf.square(t1 - t2))
print(mse(prediction,targets))
# Out:
# tf.Tensor(1502.7721800145998, shape=(), dtype=float64)

# %%
epochs = 40
for epoch_count in range(epochs):
    
    with tf.GradientTape(persistent=True) as t:
        current_loss = mse(targets, model(inputs))

    v1 = t.gradient(current_loss,v)
    r1 = t.gradient(current_loss,r)

    v.assign_sub(1e-4 * v1)
    r.assign_sub(1e-4 * r1)
        
    print(f" \n Epoch count: {epoch_count} \n Loss value: {current_loss.numpy()}")
# Out:
#
#  Epoch count: 0
#  Loss value: 1502.7721800145998
#
#  Epoch count: 1
#  Loss value: 1158.6134557434298
#
#  Epoch count: 2
#  Loss value: 916.9589817833267
#
#  Epoch count: 3
#  Loss value: 742.655098354686
#
#  Epoch count: 4
#  Loss value: 613.3144504314281
#
#  Epoch count: 5
#  Loss value: 514.5847267859054
#
#  Epoch count: 6
#  Loss value: 437.1828535911831
#
#  Epoch count: 7
#  Loss value: 375.0343789763931
#
#  Epoch count: 8
#  Loss value: 324.1049007723999
#
#  Epoch count: 9
#  Loss value: 281.66499534141803
#
#  Epoch count: 10
#  Loss value: 245.82683569390403
#
#  Epoch count: 11
#  Loss value: 215.25120963984725
#
#  Epoch count: 12
#  Loss value: 188.96151879599537
#
#  Epoch count: 13
#  Loss value: 166.2250371416717
#
#  Epoch count: 14
#  Loss value: 146.47653881564116
#
#  Epoch count: 15
#  Loss value: 129.26868806719975
#
#  Epoch count: 16
#  Loss value: 114.23939621290587
#
#  Epoch count: 17
#  Loss value: 101.089990229445
#
#  Epoch count: 18
#  Loss value: 89.57031802538584
#
#  Epoch count: 19
#  Loss value: 79.46834501773023
#
#  Epoch count: 20
#  Loss value: 70.60269358312067
#
#  Epoch count: 21
#  Loss value: 62.81714036139313
#
#  Epoch count: 22
#  Loss value: 55.97644085801954
#
#  Epoch count: 23
#  Loss value: 49.963074303751085
#
#  Epoch count: 24
#  Loss value: 44.67464309973534
#
#  Epoch count: 25
#  Loss value: 40.021750969612064
#
#  Epoch count: 26
#  Loss value: 35.926241301201905
#
#  Epoch count: 27
#  Loss value: 32.31971408652277
#
#  Epoch count: 28
#  Loss value: 29.14226388321696
#
#  Epoch count: 29
#  Loss value: 26.34139704521378
#
#  Epoch count: 30
#  Loss value: 23.87109707349625
#
#  Epoch count: 31
#  Loss value: 21.6910141879601
#
#  Epoch count: 32
#  Loss value: 19.76576029822616
#
#  Epoch count: 33
#  Loss value: 18.064294202173446
#
#  Epoch count: 34
#  Loss value: 16.559384541546045
#
#  Epoch count: 35
#  Loss value: 15.22714009895176
#
#  Epoch count: 36
#  Loss value: 14.046598626803332
#
#  Epoch count: 37
#  Loss value: 12.999366684934435
#
#  Epoch count: 38
#  Loss value: 12.069304015063198
#
#  Epoch count: 39
#  Loss value: 11.242246854596136
